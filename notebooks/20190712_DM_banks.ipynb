# %%
import os
import sys
import pandas as pd

from iexfinance.stocks import Stock 
from iexfinance.refdata import get_symbols

conf_dir = os.path.join(os.getcwd(), '..', 'conf')
sys.path.append(conf_dir)

# %%
from local import Secrets

# %%
key = Secrets.key

# %%
boh = Stock('BOH', output_format = 'pandas', token = key)
boh.get_balance_sheet()
# Out:
#                                  BOH
#                           2019-03-31
# accountsPayable                 None
# capitalSurplus             574594000
# commonStock                   578000
# currentAssets              649765000
# currentCash                     None
# currentLongTermDebt           825000
# goodwill                    31517000
# intangibleAssets                   0
# inventory                       None
# longTermDebt               609799000
# longTermInvestments         37699000
# minorityInterest                   0
# netTangibleAssets         1238173000
# otherAssets                431929000
# otherCurrentAssets              None
# otherCurrentLiabilities      8474000
# otherLiabilities           254147000
# propertyPlantEquipment     263510000
# receivables                     None
# reportDate                2019-03-31
# retainedEarnings          1674264000
# shareholderEquity         1269690000
# shortTermInvestments            None
# ...

# %%
df = pd.read_csv('../references/banks_tickers.txt', sep='\t')
df.head()
# Out:
#    Unnamed: 0                Unnamed: 1 Unnamed: 2
# 0           1       Ally Financial Inc.       ALLY
# 1           2      Associated Banc-Corp        ASB
# 2           3      Axos Financial, Inc.         AX
# 3           4  Banc of California, Inc.       BANC
# 4           5         BancorpSouth Bank        BXS

# %%
jpm = Stock('JPM', output_format = 'pandas', token = key)
jpm.get_balance_sheet()
# Out:
#                                    JPM
#                             2019-03-31
# accountsPayable                   None
# capitalSurplus             88170000000
# commonStock                 4105000000
# currentAssets            1207628000000
# currentCash                       None
# currentLongTermDebt               None
# goodwill                   47474000000
# intangibleAssets             737000000
# inventory                         None
# longTermDebt              325410000000
# longTermInvestments       289343000000
# minorityInterest                     0
# netTangibleAssets         212363000000
# otherAssets               115654000000
# otherCurrentAssets                None
# otherCurrentLiabilities  1579813000000
# otherLiabilities          364518000000
# propertyPlantEquipment     32432000000
# receivables                       None
# reportDate                  2019-03-31
# retainedEarnings          205437000000
# shareholderEquity         259837000000
# ...
