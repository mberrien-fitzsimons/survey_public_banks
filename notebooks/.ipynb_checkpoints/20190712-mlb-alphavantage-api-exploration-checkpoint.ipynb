# %% [markdown]
# ### API Exploration: Alpha Advantage
#
# This document includes examples of all API calls from Alpha Advantage. API includes the following information:
# 1. Stock Time Series Data,
# 1. Physical and Digital/Crypto Currencies (e.g., Bitcoin),
# 1. Technical Indicators, and
# 1. Sector Performances.

# %% [markdown]
# ##### Source: https://www.alphavantage.co/

# %%
import os
import sys
import pandas as pd
import requests

from iexfinance.stocks import Stock 
from iexfinance.refdata import get_symbols

conf_dir = os.path.join(os.getcwd(), '..', 'conf')
sys.path.append(conf_dir)

from local import Secrets

# %%
# api key from alpha vantage 
ALPHA_VANTAGE_KEY = Secrets.ALPHA_VANTAGE_KEY

# %% [markdown]
# #### Stock Time Series Data
#
# This API gives information on the stock of your choice. This information can be obtained in daily, weekly and monthly intervals.

# %%
ALPHA_VANTAGE_KEY = Secrets.ALPHA_VANTAGE_KEY

function = 'TIME_SERIES_DAILY'
symbol = 'MSFT'
datatype = 'csv'

url = f"https://www.alphavantage.co/query?function={function}&symbol={symbol}&datatype={datatype}&apikey={ALPHA_VANTAGE_KEY}"

# %%
msft = pd.read_csv(url)
msft.head()
# Out:
#     timestamp    open    high       low   close    volume
# 0  2019-07-12  138.85  139.13  138.0099  138.90  18884297
# 1  2019-07-11  138.20  139.22  137.8700  138.40  22327942
# 2  2019-07-10  137.13  138.58  137.0200  137.85  24204362
# 3  2019-07-09  136.00  136.97  135.8000  136.46  19953097
# 4  2019-07-08  136.40  137.10  135.3701  136.96  16779748

# %% [markdown]
# #### Physical and Digital/Crypto Currencies (e.g., Bitcoin)
#
# This API provides information on daily crypotocurrency pricing for the cryptocurrency and country currency of your coice.

# %%
# DIGITAL_CURRENCY_DAILY
function = 'DIGITAL_CURRENCY_DAILY'
symbol = 'BTC'
market = 'CNY'
datatype = 'csv'

url = f"https://www.alphavantage.co/query?function={function}&symbol={symbol}&market={market}&apikey={ALPHA_VANTAGE_KEY}&datatype={datatype}"

# %%
btc = pd.read_csv(url)
btc.head()
# Out:
#     timestamp    open (CNY)    high (CNY)     low (CNY)   close (CNY)  \
# 0  2019-07-12  82423.131729  82423.131729  81243.813294  81676.350000
# 1  2019-07-11  88458.260000  88516.180000  82429.709225  82429.709225
# 2  2019-07-10  86526.255049  88758.953306  86526.255049  88467.990000
# 3  2019-07-09  81823.560000  86525.834996  81823.560000  86525.834996
# 4  2019-07-08  79066.920000  81799.470000  79054.190000  81799.470000
#
#      open (USD)    high (USD)     low (USD)   close (USD)     volume  \
# 0  11997.195367  11997.195367  11815.391763  11870.103167  52.904318
# 1  12869.909888  12884.413618  11998.152762  11998.152762  46.232263
# 2  12559.695198  12913.961726  12559.695198  12871.325518  61.585794
# 3  11889.848603  12559.634226  11889.848603  12559.634226  67.207641
# 4  11469.528855  11886.348066  11467.932043  11886.348066  84.175678
#
#    market cap (USD)
# 0      6.279797e+05
# 1      5.547017e+05
# 2      7.926908e+05
# 3      8.441034e+05
# 4      1.000541e+06

# %% [markdown]
# ####  Technical Indicators

# %%
# SMA
function = 'SMA'
symbol = 'USDEUR'
interval = 'weekly'
time_period = 10
series_type = 'open'
datatype = 'csv'

url = f"https://www.alphavantage.co/query?function={function}&symbol={symbol}&interval={interval}&time_period=10&series_type={series_type}&apikey={ALPHA_VANTAGE_KEY}&datatype={datatype}"

# %%
sma_usdeur = pd.read_csv(url)
sma_usdeur.head()
# Out:
#          time     SMA
# 0  2019-07-11  0.8891
# 1  2019-07-04  0.8897
# 2  2019-06-27  0.8907
# 3  2019-06-20  0.8913
# 4  2019-06-13  0.8912

# %% [markdown]
# #### Sector Performances

# %%
function = 'SECTOR'

url = f'https://www.alphavantage.co/query?function={function}&apikey={ALPHA_VANTAGE_KEY}'
response = requests.get(url)

# %%
response.json()
# Out:
# {'Meta Data': {'Information': 'US Sector Performance (realtime & historical)',
#   'Last Refreshed': '04:20 PM ET 07/12/2019'},
#  'Rank A: Real-Time Performance': {'Industrials': '1.78%',
#   'Consumer Discretionary': '1.06%',
#   'Materials': '1.02%',
#   'Information Technology': '0.80%',
#   'Communication Services': '0.63%',
#   'Financials': '0.61%',
#   'Energy': '0.37%',
#   'Consumer Staples': '0.33%',
#   'Real Estate': '-0.39%',
#   'Utilities': '-0.64%',
#   'Health Care': '-1.18%'},
#  'Rank B: 1 Day Performance': {'Industrials': '1.78%',
#   'Consumer Discretionary': '1.06%',
#   'Materials': '1.02%',
#   'Information Technology': '0.80%',
#   'Communication Services': '0.63%',
#   'Financials': '0.61%',
#   'Energy': '0.37%',
#   'Consumer Staples': '0.33%',
#   'Real Estate': '-0.39%',
#   'Utilities': '-0.64%',
#   'Health Care': '-1.18%'},
#  'Rank C: 5 Day Performance': {'Energy': '2.15%',
#   'Consumer Discretionary': '2.14%',
#   'Information Technology': '1.52%',
#   'Industrials': '1.24%',
#   'Communication Services': '1.19%',
#   'Consumer Staples': '0.90%',
#   'Financials': '0.46%',
#   'Utilities': '-0.11%',
#   'Real Estate': '-0.20%',
#   'Materials': '-0.82%',
#   'Health Care': '-1.43%'},
#  'Rank D: 1 Month Performance': {'Communication Services': '7.24%',
#   'Consumer Discretionary': '6.42%',
#   'Information Technology': '5.75%',
#   'Energy': '5.57%',
#   'Industrials': '4.71%',
#   'Financials': '3.83%',
#   'Utilities': '3.01%',
#   'Consumer Staples': '2.35%',
#   'Materials': '1.82%',
#   'Health Care': '1.75%',
#   'Real Estate': '1.00%'},
#  'Rank E: 3 Month Performance': {'Consumer Staples': '6.52%',
#   'Information Technology': '6.44%',
#   'Financials': '6.30%',
#   'Consumer Discretionary': '5.87%',
#   'Communication Services': '4.84%',
#   'Utilities': '4.67%',
#   'Real Estate': '3.12%',
#   'Industrials': '2.75%',
#   'Materials': '1.94%',
#   'Health Care': '1.91%',
#   'Energy': '-4.37%'},
#  'Rank F: Year-to-Date (YTD) Performance': {'Information Technology': '30.89%',
#   'Consumer Discretionary': '26.15%',
#   'Communication Services': '23.02%',
#   'Industrials': '21.82%',
#   'Real Estate': '21.13%',
#   'Financials': '18.71%',
#   'Consumer Staples': '18.01%',
#   'Materials': '15.61%',
#   'Utilities': '14.50%',
#   'Energy': '12.46%',
#   'Health Care': '6.83%'},
#  'Rank G: 1 Year Performance': {'Utilities': '15.57%',
#   'Communication Services': '14.36%',
#   'Real Estate': '14.29%',
#   'Consumer Staples': '14.28%',
#   'Information Technology': '13.64%',
#   'Consumer Discretionary': '10.99%',
#   'Industrials': '8.36%',
#   'Health Care': '7.13%',
#   'Financials': '4.70%',
#   'Materials': '-0.06%',
#   'Energy': '-14.82%'},
#  'Rank H: 3 Year Performance': {'Information Technology': '94.89%',
#   'Consumer Discretionary': '53.14%',
#   'Financials': '51.20%',
#   'Industrials': '31.92%',
#   'Health Care': '25.92%',
#   'Materials': '23.80%',
#   'Utilities': '15.34%',
#   'Consumer Staples': '7.77%',
#   'Communication Services': '-6.02%',
#   'Energy': '-6.46%'},
#  'Rank I: 5 Year Performance': {'Information Technology': '122.53%',
#   'Consumer Discretionary': '84.43%',
#   'Financials': '53.74%',
#   'Health Care': '50.03%',
#   'Industrials': '41.79%',
#   'Utilities': '41.25%',
#   'Consumer Staples': '32.30%',
#   'Materials': '16.85%',
#   'Communication Services': '5.81%',
#   'Energy': '-33.51%'},
#  'Rank J: 10 Year Performance': {'Consumer Discretionary': '467.38%',
#   'Information Technology': '413.38%',
#   'Industrials': '264.97%',
#   'Health Care': '258.31%',
#   'Financials': '214.72%',
#   'Consumer Staples': '159.48%',
#   'Materials': '150.85%',
#   'Utilities': '124.59%',
#   'Communication Services': '74.57%',
#   'Energy': '37.18%'}}
